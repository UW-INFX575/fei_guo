# %%
from bs4 import BeautifulSoup
from urllib2 import urlopen, Request, HTTPError, URLError
from time import sleep # be nice
import re
import os
import unicodedata
import numpy as np

# %%
def make_soup(url):
    req = Request(url, headers ={'User-Agent':'Chrome'})
    try:
        html = urlopen(req).read()
        return BeautifulSoup(html, "lxml")
    except (URLError, HTTPError) as e:
#         print e.fp.read()
        print "Error"


def get_review_links(section_url):
    soup = make_soup(section_url)

    games = soup.findAll("div", { "class":"up-com grid_7" })

    link = []
    for i in range(len(games)):
        li = games[i].find("ul", { "class":"item-quickLinks clear" }).find('a', href = True)
        link.append(li['href'])
        link = list(set(link))
        
    return link


def get_review(section_url):
    soup = make_soup(section_url)
    if (soup != None): 
        reviewer = soup.find("div", { "id":"creator-name" }).text
        reviewer = unicodedata.normalize('NFKD', reviewer).encode('ascii','ignore')
        reviewer = reviewer.strip()

        reviewDate = soup.find("span", { "class":"review-date" }).text
        reviewDate = unicodedata.normalize('NFKD', reviewDate).encode('ascii','ignore')
        reviewDate = reviewDate.strip()

        title = soup.find("h2", { "class":"object-name" }).text
        title = unicodedata.normalize('NFKD', title).encode('ascii','ignore')
        title = title.strip()

        body = soup.find("div", { "id":"review-body" })
        texts = body.findAll("p")
        review = []
        for i in texts:
            review.append(unicodedata.normalize('NFKD', i.text).encode('ascii','ignore'))
    else: 
        print "page inaccessible:" + section_url
        title = ''
        reviewer = ''
        reviewDate = ''
        review = ''
    return title, reviewer, reviewDate, review

# %%
url  = ("http://www.ign.com/games/reviews")
urls = []
for i in range(50):
    urls.append(url + '?startIndex=' + str(25*i))
urls
# Out:
# ['http://www.ign.com/games/reviews?startIndex=0',
#  'http://www.ign.com/games/reviews?startIndex=25',
#  'http://www.ign.com/games/reviews?startIndex=50',
#  'http://www.ign.com/games/reviews?startIndex=75',
#  'http://www.ign.com/games/reviews?startIndex=100',
#  'http://www.ign.com/games/reviews?startIndex=125',
#  'http://www.ign.com/games/reviews?startIndex=150',
#  'http://www.ign.com/games/reviews?startIndex=175',
#  'http://www.ign.com/games/reviews?startIndex=200',
#  'http://www.ign.com/games/reviews?startIndex=225',
#  'http://www.ign.com/games/reviews?startIndex=250',
#  'http://www.ign.com/games/reviews?startIndex=275',
#  'http://www.ign.com/games/reviews?startIndex=300',
#  'http://www.ign.com/games/reviews?startIndex=325',
#  'http://www.ign.com/games/reviews?startIndex=350',
#  'http://www.ign.com/games/reviews?startIndex=375',
#  'http://www.ign.com/games/reviews?startIndex=400',
#  'http://www.ign.com/games/reviews?startIndex=425',
#  'http://www.ign.com/games/reviews?startIndex=450',
#  'http://www.ign.com/games/reviews?startIndex=475',
#  'http://www.ign.com/games/reviews?startIndex=500',
#  'http://www.ign.com/games/reviews?startIndex=525',
#  'http://www.ign.com/games/reviews?startIndex=550',
#  'http://www.ign.com/games/reviews?startIndex=575',
#  'http://www.ign.com/games/reviews?startIndex=600',
#  'http://www.ign.com/games/reviews?startIndex=625',
#  'http://www.ign.com/games/reviews?startIndex=650',
#  'http://www.ign.com/games/reviews?startIndex=675',
#  'http://www.ign.com/games/reviews?startIndex=700',
#  'http://www.ign.com/games/reviews?startIndex=725',
#  'http://www.ign.com/games/reviews?startIndex=750',
#  'http://www.ign.com/games/reviews?startIndex=775',
#  'http://www.ign.com/games/reviews?startIndex=800',
#  'http://www.ign.com/games/reviews?startIndex=825',
#  'http://www.ign.com/games/reviews?startIndex=850',
#  'http://www.ign.com/games/reviews?startIndex=875',
#  'http://www.ign.com/games/reviews?startIndex=900',
#  'http://www.ign.com/games/reviews?startIndex=925',
#  'http://www.ign.com/games/reviews?startIndex=950',
#  'http://www.ign.com/games/reviews?startIndex=975',
#  'http://www.ign.com/games/reviews?startIndex=1000',
#  'http://www.ign.com/games/reviews?startIndex=1025',
#  'http://www.ign.com/games/reviews?startIndex=1050',
#  'http://www.ign.com/games/reviews?startIndex=1075',
#  'http://www.ign.com/games/reviews?startIndex=1100',
#  'http://www.ign.com/games/reviews?startIndex=1125',
#  'http://www.ign.com/games/reviews?startIndex=1150',
#  'http://www.ign.com/games/reviews?startIndex=1175',
#  'http://www.ign.com/games/reviews?startIndex=1200',
#  'http://www.ign.com/games/reviews?startIndex=1225']

# %%
titles = []
reviewDates = []
reviews = []
reviewers = []
review_link = []
for url in range(len(urls)):
    links = get_review_links(urls[url])
    for link in links:
        print link
        title, reviewer, reviewDate, review = get_review(link)
        titles.append(title)
        reviewDates.append(reviewDate)
        reviews.append(review)
        reviewers.append(reviewer)
        review_link.append(link)
# Out:
# http://www.ign.com/articles/2015/04/21/halo-spartan-strike-review
# http://www.ign.com/articles/2015/04/23/the-evil-within-the-consequence-review
# http://www.ign.com/articles/2015/04/22/state-of-decay-year-one-survival-edition-review
# http://www.ign.com/articles/2015/04/21/crypt-of-the-necrodancer-review
# http://www.ign.com/articles/2015/04/13/i-am-bread-review
# http://www.ign.com/articles/2015/05/05/boxboy-review
# http://www.ign.com/articles/2015/04/26/broken-age-act-2-review
# http://www.ign.com/articles/2015/05/08/wolfenstein-the-old-blood-review
# http://www.ign.com/articles/2015/04/20/stardrive-2-review
# http://www.ign.com/articles/2015/04/21/assassins-creed-chronicles-china-review
# http://www.ign.com/articles/2015/05/01/story-of-seasons-review
# http://www.ign.com/articles/2015/05/05/magicka-wizard-wars-review
# http://www.ign.com/articles/2015/04/14/gta-5-pc-review
# http://www.ign.com/articles/2015/05/05/shadowrun-chronicles-boston-lockdown-review
# http://www.ign.com/articles/2015/04/29/infinite-crisis-review
# http://www.ign.com/articles/2015/04/21/dungeons-2-review
# http://www.ign.com/articles/2015/05/06/project-cars-review
# http://www.ign.com/articles/2015/03/24/borderlands-the-handsome-collection-review
# http://www.ign.com/articles/2015/04/13/mortal-kombat-x-review
# http://www.ign.com/articles/2015/03/19/resident-evil-revelations-2-review
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-206-b70b787b26e5> in <module>()
#       8     for link in links:
#       9         print link
# ---> 10         title, reviewer, reviewDate, review = get_review(link)
#      11         titles.append(title)
#      12         reviewDates.append(reviewDate)
#
# <ipython-input-200-91a675550a52> in get_review(section_url)
#      24
#      25 def get_review(section_url):
# ---> 26     soup = make_soup(section_url)
#      27     if (soup != None):
#      28         reviewer = soup.find("div", { "id":"creator-name" }).text
#
# <ipython-input-200-91a675550a52> in make_soup(url)
#       2     req = Request(url, headers ={'User-Agent':'Chrome'})
#       3     try:
# ----> 4         html = urlopen(req).read()
#       5         return BeautifulSoup(html, "lxml")
#       6     except (URLError, HTTPError) as e:
#
# /Users/feismacbookpro/anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /Users/feismacbookpro/anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /Users/feismacbookpro/anaconda/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /Users/feismacbookpro/anaconda/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /Users/feismacbookpro/anaconda/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1225
#    1226     def http_open(self, req):
# -> 1227         return self.do_open(httplib.HTTPConnection, req)
#    1228
#    1229     http_request = AbstractHTTPHandler.do_request_
#
# /Users/feismacbookpro/anaconda/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1198         else:
#    1199             try:
# -> 1200                 r = h.getresponse(buffering=True)
#    1201             except TypeError: # buffering kw not supported
#    1202                 r = h.getresponse()
#
# /Users/feismacbookpro/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1071         response = self.response_class(*args, **kwds)
#    1072
# -> 1073         response.begin()
#    1074         assert response.will_close != _UNKNOWN
#    1075         self.__state = _CS_IDLE
#
# /Users/feismacbookpro/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     413         # read until we get a non-100 response
#     414         while True:
# --> 415             version, status, reason = self._read_status()
#     416             if status != CONTINUE:
#     417                 break
#
# /Users/feismacbookpro/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     369     def _read_status(self):
#     370         # Initialize with Simple-Response defaults
# --> 371         line = self.fp.readline(_MAXLINE + 1)
#     372         if len(line) > _MAXLINE:
#     373             raise LineTooLong("header line")
#
# /Users/feismacbookpro/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# error: [Errno 60] Operation timed out

# %%
# put all lists together
IGN = titles, reviewDates, reviewers, review_link, reviews

# output to a csv file, results needs to be transposed as the list is by default verticalled stacked
import csv
with open("IGN.csv", "wb") as f:
    writer = csv.writer(f) 
    for row in IGN:
        writer.writerow(row)
